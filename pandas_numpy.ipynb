# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas Series

# %%
s = pd.Series([1, 3, 'text', -9])

# %%
type(s)
# Out:
# pandas.core.series.Series

# %%
s2 = pd.Series([1, 3, np.nan, -9])

# %%
s2
# Out:
# 0    1.0
# 1    3.0
# 2    NaN
# 3   -9.0
# dtype: float64

# %%
dates = pd.date_range('20200101', periods=8)

# %%
dates
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08'],
#               dtype='datetime64[ns]', freq='D')

# %%
df = pd.DataFrame(data=np.random.randn(8, 4), index=dates, columns = "A B C D".split())

# %%
np.random.randn(10, 2)
# Out:
# array([[-0.37691588, -0.41500262],
#        [ 0.77277484, -2.25892634],
#        [-1.55502955, -0.15243931],
#        [-1.36479016, -0.54190363],
#        [ 0.93775775, -0.19309832],
#        [-1.96985956, -0.78482177],
#        [ 0.3058221 ,  0.80089548],
#        [ 0.10394036,  0.56851631],
#        [ 1.76030471,  1.14874947],
#        [-0.77979159,  1.34792866]])

# %%
list(range(8))
# Out:
# [0, 1, 2, 3, 4, 5, 6, 7]

# %%
df = pd.DataFrame(data=np.random.randn(8, 4), columns = "A B C D".split())

# %%
df
# Out:
#           A         B         C         D
# 0  0.723514  1.614734 -0.952714 -0.961433
# 1 -0.701354 -0.106554 -0.617708 -0.510049
# 2  2.332312 -0.734946  0.788754  0.430347
# 3 -1.024537  0.845551  0.222611  0.358885
# 4 -0.083459  1.375554 -0.647906  0.676753
# 5 -0.321418 -2.579422  0.080578 -2.649184
# 6 -0.234875  0.197390  0.669734  0.175108
# 7 -0.153119  1.159823 -0.483061 -0.355045

# %%
df
# Out:
#                    A         B         C         D
# 2020-01-01 -0.282705 -0.446831  1.333444 -0.499867
# 2020-01-02  1.323749  0.385528  2.537647 -0.847421
# 2020-01-03 -0.159016 -0.664057  0.660372  0.539689
# 2020-01-04 -0.142923  0.165215 -0.682734 -1.018871
# 2020-01-05 -1.152045  2.247721  1.637248  2.527615
# 2020-01-06  0.574319  0.584778  1.604294  0.824370
# 2020-01-07 -1.213631 -0.990975 -0.048638 -1.135744
# 2020-01-08  0.828708 -1.957736 -0.548054  0.036664

# %%
mydictionary = {'A':[1, 2, 3], 'B':["str", 34, -90], 'c': 45}

pd.DataFrame(data=mydictionary)
# Out:
#    A    B   c
# 0  1  str  45
# 1  2   34  45
# 2  3  -90  45

# %%
[3]*2
# Out:
# [3, 3]

# %%
mydictionary = { 
    'A' :[12]*4, 
    'B' : pd.Timestamp('20200203'),
    'C': pd.Series(3, index=list(range(4)), dtype='float32'),
    'D': np.array([1, 2, 4, 0]), 
    'E': pd.Categorical(['str1', 'test', 'pandas', 'numpy']),
    'F': 45,
    'G': 'string for all rows'
}

df2 = pd.DataFrame(mydictionary)

# %%
df2
# Out:
#     A          B    C  D       E   F                    G
# 0  12 2020-02-03  3.0  1    str1  45  string for all rows
# 1  12 2020-02-03  3.0  2    test  45  string for all rows
# 2  12 2020-02-03  3.0  4  pandas  45  string for all rows
# 3  12 2020-02-03  3.0  0   numpy  45  string for all rows

# %%
{'a':20, 'b': [23, 324, 45]}
# Out:
# {'a': 20, 'b': [23, 324, 45]}

# %%
pd.Timestamp('20200203')
# Out:
# Timestamp('2020-02-03 00:00:00')

# %%
pd.Series(3, index=list(range(4)))
# Out:
# 0    3
# 1    3
# 2    3
# 3    3
# dtype: int64

# %%
pd.Categorical(['str1', 'test', 'pandas', 'numpy'])
# Out:
# [str1, test, pandas, numpy]
# Categories (4, object): [numpy, pandas, str1, test]

# %%
df2
# Out:
#     A          B  C  D       E   F                    G
# 0  12 2020-02-03  3  1    str1  45  string for all rows
# 1  12 2020-02-03  3  2    test  45  string for all rows
# 2  12 2020-02-03  3  4  pandas  45  string for all rows
# 3  12 2020-02-03  3  0   numpy  45  string for all rows

# %%
df2.dtypes
# Out:
# A             int64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F             int64
# G            object
# dtype: object

# %%
df2
# Out:
#     A          B    C  D       E   F                    G
# 0  12 2020-02-03  3.0  1    str1  45  string for all rows
# 1  12 2020-02-03  3.0  2    test  45  string for all rows
# 2  12 2020-02-03  3.0  4  pandas  45  string for all rows
# 3  12 2020-02-03  3.0  0   numpy  45  string for all rows

# %%
import pandas as pd
import numpy as np

dates = pd.date_range('20200101', periods=200)
df = pd.DataFrame(data=np.random.randn(200, 10), index=dates, columns = "A B C D E F G H I J".split())

# %%
df
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-01  1.031558 -0.037983  0.995923  0.215910  0.405482  0.441409
# 2020-01-02  1.210610  0.307088 -0.395456 -1.032209 -0.086030  0.929924
# 2020-01-03  1.042559 -2.065327  0.201607  0.581618 -0.852262  0.159259
# 2020-01-04 -1.268735  0.654950  0.350343 -0.617579  0.799575 -1.490695
# 2020-01-05  1.534127  0.553398  0.349324  0.802871  1.735758 -0.849070
# ...              ...       ...       ...       ...       ...       ...
# 2020-07-14  0.070630  0.637740  0.216158 -0.398602 -0.458087 -0.372938
# 2020-07-15 -1.322362  0.565195  0.478909  1.275585  0.911405  0.038425
# 2020-07-16  0.151065 -0.603632 -0.957951  2.288862  0.057442 -0.349818
# 2020-07-17  0.036269  1.858562 -0.593726 -0.668770 -0.676072  1.332702
# 2020-07-18  1.198581 -1.150890  1.371643 -0.027445  0.494152  0.104598
#
#                    G         H         I         J
# 2020-01-01  2.140098  0.046438  0.639571 -1.082221
# ...

# %%
df.shape
# Out:
# (200, 10)

# %%
df.head()
# Out:
#                    A         B         C         D         E         F  \
# 2020-01-01  1.031558 -0.037983  0.995923  0.215910  0.405482  0.441409
# 2020-01-02  1.210610  0.307088 -0.395456 -1.032209 -0.086030  0.929924
# 2020-01-03  1.042559 -2.065327  0.201607  0.581618 -0.852262  0.159259
# 2020-01-04 -1.268735  0.654950  0.350343 -0.617579  0.799575 -1.490695
# 2020-01-05  1.534127  0.553398  0.349324  0.802871  1.735758 -0.849070
#
#                    G         H         I         J
# 2020-01-01  2.140098  0.046438  0.639571 -1.082221
# 2020-01-02 -1.202661 -0.522852 -0.868041  1.217336
# 2020-01-03  1.983552 -0.713619 -0.287356  1.233328
# 2020-01-04  0.407228 -1.252842  0.877651  0.766256
# 2020-01-05 -1.295748  2.465528 -0.274723  0.540473

# %%
df.tail(1)
# Out:
#                    A        B         C         D         E         F  \
# 2020-07-18  1.198581 -1.15089  1.371643 -0.027445  0.494152  0.104598
#
#                    G         H        I         J
# 2020-07-18 -0.172626  0.520939 -0.80801  0.093526

# %%
df.index
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10',
#                ...
#                '2020-07-09', '2020-07-10', '2020-07-11', '2020-07-12',
#                '2020-07-13', '2020-07-14', '2020-07-15', '2020-07-16',
#                '2020-07-17', '2020-07-18'],
#               dtype='datetime64[ns]', length=200, freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H', 'I', 'J'], dtype='object')

# %%
df.describe()
# Out:
#                 A           B           C           D           E           F  \
# count  200.000000  200.000000  200.000000  200.000000  200.000000  200.000000
# mean     0
# 2020-07-14  0.070630  0.637740  0.216158 -0.398602 -0.458087 -0.372938
# 2020-07-15 -1.322362  0.565195  0.478909  1.275585  0.911405  0.038425
# 2020-07-16  0.151065 -0.603632 -0.957951  2.288862  0.057442 -0.349818
# 2020-07-17  0.036269  1.858562 -0.593726 -0.668770 -0.676072  1.332702
# 2020-07-18  1.198581 -1.150890  1.371643 -0.027445  0.494152  0.104598
#
#                    G         H         I         J
# index
# ...

# %%
df['A'] = 20

# %%
df
# Out:
#              A         B         C         D         E         F         G  \
# index
# 2020-01-01  20 -0.037983  0.995923  0.215910  0.405482  0.441409  2.140098
# 2020-01-02  20  0.307088 -0.395456 -1.032209 -0.086030  0.929924 -1.202661
# 2020-01-03  20 -2.065327  0.201607  0.581618 -0.852262  0.159259  1.983552
# 2020-01-04  20  0.654950  0.350343 -0.617579  0.799575 -1.490695  0.407228
# 2020-01-05  20  0.553398  0.349324  0.802871  1.735758 -0.849070 -1.295748
# ...         ..       ...       ...       ...       ...       ...       ...
# 2020-07-14  20  0.637740  0.216158 -0.398602 -0.458087 -0.372938 -0.786025
# 2020-07-15  20  0.565195  0.478909  1.275585  0.911405  0.038425 -1.714019
# 2020-07-16  20 -0.603632 -0.957951  2.288862  0.057442 -0.349818 -1.048517
# 2020-07-17  20  1.858562 -0.593726 -0.668770 -0.676072  1.332702  0.880967
# 2020-07-18  20 -1.150890  1.371643 -0.027445  0.494152  0.104598 -0.172626
#
#                    H         I         J
# index
# ...

# %%
df['K'] = np.random.randn(200)/200000

# %%
df
# Out:
#              A         B         C         D         E         F         G  \
# index
# 2020-01-01  20 -0.037983  0.995923  0.215910  0.405482  0.441409  2.140098
# 2020-01-02  20  0.307088 -0.395456 -1.032209 -0.086030  0.929924 -1.202661
# 2020-01-03  20 -2.065327  0.201607  0.581618 -0.852262  0.159259  1.983552
# 2020-01-04  20  0.654950  0.350343 -0.617579  0.799575 -1.490695  0.407228
# 2020-01-05  20  0.553398  0.349324  0.802871  1.735758 -0.849070 -1.295748
# ...         ..       ...       ...       ...       ...       ...       ...
# 2020-07-14  20  0.637740  0.216158 -0.398602 -0.458087 -0.372938 -0.786025
# 2020-07-15  20  0.565195  0.478909  1.275585  0.911405  0.038425 -1.714019
# 2020-07-16  20 -0.603632 -0.957951  2.288862  0.057442 -0.349818 -1.048517
# 2020-07-17  20  1.858562 -0.593726 -0.668770 -0.676072  1.332702  0.880967
# 2020-07-18  20 -1.150890  1.371643 -0.027445  0.494152  0.104598 -0.172626
#
#                    H         I         J              K
# ...

# %%
myarr = np.random.randn(3)

# %%
myarr
# Out:
# array([-0.66753368,  0.50351417,  1.08616376])

# %%
myarr / 2
# Out:
# array([-0.33376684,  0.25175708,  0.54308188])

# %%
mylist = [40, 30, 10] / 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-f992ad0500e5> in <module>
# ----> 1 mylist = [40, 30, 10] / 2
#
# TypeError: unsupported operand type(s) for /: 'list' and 'int'

# %%
mylist * 2
# Out:
# [40, 30, 10, 40, 30, 10]

# %%
np.random.randn(200) * 1000000
# Out:
# array([-1.66669579e+05, -4.39116164e+05, -1.60181046e+06, -7.53161654e+05,
#        -4.81989541e+05,  3.75144585e+04,  7.44221519e+05,  1.04675718e+05,
#        -2.60600616e+05,  4.22670954e+05, -6.49122591e+05,  4.40858411e+05,
#        -1.42836212e+06,  1.00556643e+06,  1.32043458e+06,  4.33781501e+03,
#        -2.81009060e+06, -3.19154420e+05, -2.06808669e+06, -8.64776052e+05,
#        -2.54448506e+06,  1.64237831e+05,  1.64912182e+05,  1.12758477e+06,
#        -1.63269386e+06, -2.58229607e+05,  5.40409796e+05,  1.29164898e+06,
#         1.18296045e+06, -8.29186540e+04,  9.09971372e+05,  8.42520508e+05,
#         1.01294966e+06, -1.29548886e+06,  1.44439643e+06,  1.34849270e+05,
#         1.09547509e+06,  1.42619970e+06,  8.09396486e+05, -2.53378606e+05,
#         4.93212177e+05, -7.06346201e+05,  7.39069795e+05, -2.54519707e+04,
#         2.20321633e+06, -2.72742050e+05, -1.65503782e+06, -9.45072144e+05,
# ...

# %%
df = df.reset_index()

# %%
df
# Out:
#          index   A         B         C         D         E         F  \
# 0   2020-01-01  20 -0.037983  0.995923  0.215910  0.405482  0.441409
# 1   2020-01-02  20  0.307088 -0.395456 -1.032209 -0.086030  0.929924
# 2   2020-01-03  20 -2.065327  0.201607  0.581618 -0.852262  0.159259
# 3   2020-01-04  20  0.654950  0.350343 -0.617579  0.799575 -1.490695
# 4   2020-01-05  20  0.553398  0.349324  0.802871  1.735758 -0.849070
# ..         ...  ..       ...       ...       ...       ...       ...
# 195 2020-07-14  20  0.637740  0.216158 -0.398602 -0.458087 -0.372938
# 196 2020-07-15  20  0.565195  0.478909  1.275585  0.911405  0.038425
# 197 2020-07-16  20 -0.603632 -0.957951  2.288862  0.057442 -0.349818
# 198 2020-07-17  20  1.858562 -0.593726 -0.668770 -0.676072  1.332702
# 199 2020-07-18  20 -1.150890  1.371643 -0.027445  0.494152  0.104598
#
#             G         H         I         J              K
# 0    2.140098  0.046438  0.639571 -1.082221  126967.789865
# ...

# %%
from bokeh.io import output_notebook, show
from bokeh.models import Button

output_notebook()

button = Button(label="Name", button_type="success")

show(button)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1005">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="128e97aa-351d-4cf9-890c-8b2b507ea992" data-root-id="1006"></div>

# %%
df
# Out:
#          index   A         B         C         D         E         F  \
# 0   2020-01-01  20 -0.037983  0.995923  0.215910  0.405482  0.441409
# 1   2020-01-02  20  0.307088 -0.395456 -1.032209 -0.086030  0.929924
# 2   2020-01-03  20 -2.065327  0.201607  0.581618 -0.852262  0.159259
# 3   2020-01-04  20  0.654950  0.350343 -0.617579  0.799575 -1.490695
# 4   2020-01-05  20  0.553398  0.349324  0.802871  1.735758 -0.849070
# ..         ...  ..       ...       ...       ...       ...       ...
# 195 2020-07-14  20  0.637740  0.216158 -0.398602 -0.458087 -0.372938
# 196 2020-07-15  20  0.565195  0.478909  1.275585  0.911405  0.038425
# 197 2020-07-16  20 -0.603632 -0.957951  2.288862  0.057442 -0.349818
# 198 2020-07-17  20  1.858562 -0.593726 -0.668770 -0.676072  1.332702
# 199 2020-07-18  20 -1.150890  1.371643 -0.027445  0.494152  0.104598
#
#             G         H         I         J              K
# 0    2.140098  0.046438  0.639571 -1.082221  126967.789865
# ...

# %%
from bokeh.io import output_notebook, show
from bokeh.models import DataTable, TableColumn, DateFormatter, ColumnDataSource
output_notebook()

source = ColumnDataSource(df)

columns = [
        TableColumn(field="index", title="Date", formatter=DateFormatter()),
        TableColumn(field="K", title="My New Column"),
    TableColumn(field="B", title="B"),
    ]

data_table = DataTable(source=source, columns=columns, width=600, height=280)
show(data_table)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1278">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="5a693e7f-dc73-4d2d-90f7-b0761de96cea" data-root-id="1285"></div>

# %%
df
# Out:
#          index   A         B         C         D         E         F  \
# 0   2020-01-01  20 -0.037983  0.995923  0.215910  0.405482  0.441409
# 1   2020-01-02  20  0.307088 -0.395456 -1.032209 -0.086030  0.929924
# 2   2020-01-03  20 -2.065327  0.201607  0.581618 -0.852262  0.159259
# 3   2020-01-04  20  0.654950  0.350343 -0.617579  0.799575 -1.490695
# 4   2020-01-05  20  0.553398  0.349324  0.802871  1.735758 -0.849070
# ..         ...  ..       ...       ...       ...       ...       ...
# 195 2020-07-14  20  0.637740  0.216158 -0.398602 -0.458087 -0.372938
# 196 2020-07-15  20  0.565195  0.478909  1.275585  0.911405  0.038425
# 197 2020-07-16  20 -0.603632 -0.957951  2.288862  0.057442 -0.349818
# 198 2020-07-17  20  1.858562 -0.593726 -0.668770 -0.676072  1.332702
# 199 2020-07-18  20 -1.150890  1.371643 -0.027445  0.494152  0.104598
#
#             G         H         I         J              K
# 0    2.140098  0.046438  0.639571 -1.082221  126967.789865
# ...

# %%
np.random.randn(10)
# Out:
# array([ 1.18122935, -1.43711014,  1.74895059, -0.39293564, -1.1590017 ,
#         1.91169227, -0.93804617,  1.77185688,  0.3902261 , -0.4658041 ])

# %%
import random

# %%
random.randint(20, 50)
# Out:
# 22

# %%
age_list = []

# %%
for i in range(10):
    age_list.append(random.randint(20, 50))

# %%
age_list
# Out:
# [38, 35, 26, 28, 48, 34, 28, 29, 33, 28]

# %% [markdown]
# # list comprehension

# %%
age_list = [random.randint(20, 50) for i in range(10)]
weight_list = [random.randint(60, 100) for i in range(10)]

# %%
[x+2000 for x in range(10)]
# Out:
# [2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009]

# %%
age_list
# Out:
# [22, 41, 34, 26, 27, 24, 37, 31, 46, 26]

# %%
weight_list
# Out:
# [85, 87, 100, 84, 96, 71, 77, 64, 82, 73]

# %%
df = pd.DataFrame({"Age": age_list, "Weight": weight_list})

# %%
df
# Out:
#    Age  Weight
# 0   34      85
# 1   37      87
# 2   38     100
# 3   26      84
# 4   47      96
# 5   50      71
# 6   47      77
# 7   30      64
# 8   45      82
# 9   47      73

# %%
df['Age'] > 30
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7    False
# 8     True
# 9     True
# Name: Age, dtype: bool

# %%
df['Weight'] < 70
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: Weight, dtype: bool

# %%
(df['Age'] > 30) | (df['Weight'] < 80)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4     True
# 5     True
# 6     True
# 7     True
# 8     True
# 9     True
# dtype: bool

# %%
df[(df['Age'] > 30) & (df['Weight'] < 80)]
# Out:
#    Age  Weight
# 5   50      71
# 6   47      77
# 9   47      73

# %%
df.columns
# Out:
# Index(['Age', 'Weight'], dtype='object')
